# %%
# BC2026_Test_<file ID>_<site>_<date>_<time in UTC>.ogg

# %%
import os
from os import listdir
from os.path import join, basename

# %%
path = r'data/train_soundscapes'
audios = listdir(path)

# %%
for audio
